# %%
from google.colab import drive
import h5py
drive.mount('/content/drive')
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import imageio
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
# !pip install yt
import yt
# Out:
# Collecting yt
#   Downloading yt-4.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (44.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 MB 20.4 MB/s eta 0:00:00
# Collecting cmyt>=1.1.2 (from yt)
#   Downloading cmyt-2.0.0-py3-none-any.whl (31 kB)
# Collecting ewah-bool-utils>=1.0.2 (from yt)
#   Downloading ewah_bool_utils-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 96.9 MB/s eta 0:00:00
# Collecting ipywidgets>=8.0.0 (from yt)
#   Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.10/dist-packages (from yt) (3.7.1)
# Requirement already satisfied: more-itertools>=8.4 in /usr/local/lib/python3.10/dist-packages (from yt) (10.1.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from yt) (1.23.5)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from yt) (23.2)
# Requirement already satisfied: pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from yt) (9.4.0)
# Collecting tomli-w>=0.4.0 (from yt)
#   Downloading tomli_w-1.0.0-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: tqdm>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from yt) (4.66.1)
# Collecting unyt<3.0,>=2.9.2 (from yt)
#   Downloading unyt-2.9.5-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: tomli>=1.2.3 in /usr/local/lib/python3.10/dist-packages (from yt) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from yt) (4.5.0)
# Collecting comm>=0.1.3 (from ipywidgets>=8.0.0->yt)
#   Downloading comm-0.2.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.0->yt) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.0->yt) (5.7.1)
# Collecting widgetsnbextension~=4.0.9 (from ipywidgets>=8.0.0->yt)
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 92.2 MB/s eta 0:00:00
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.0->yt) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->yt) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->yt) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->yt) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->yt) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->yt) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->yt) (2.8.2)
# Requirement already satisfied: sympy>=1.5 in /usr/local/lib/python3.10/dist-packages (from unyt<3.0,>=2.9.2->yt) (1.12)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets>=8.0.0->yt)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.2 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (3.0.41)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->yt) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.5->unyt<3.0,>=2.9.2->yt) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.0->yt) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.0.0->yt) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8.0.0->yt) (0.2.12)
# Installing collected packages: widgetsnbextension, tomli-w, jedi, ewah-bool-utils, comm, unyt, ipywidgets, cmyt, yt
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.6
#     Uninstalling widgetsnbextension-3.6.6:
#       Successfully uninstalled widgetsnbextension-3.6.6
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# Successfully installed cmyt-2.0.0 comm-0.2.0 ewah-bool-utils-1.1.0 ipywidgets-8.1.1 jedi-0.19.1 tomli-w-1.0.0 unyt-2.9.5 widgetsnbextension-4.0.9 yt-4.3.0

# %%
cd /content/drive/MyDrive/firstoutput
# Out:
# /content/drive/MyDrive/firstoutput

# %%
snapshot_dir = '/content/drive/MyDrive/firstoutput'

# %%
# Iterate through all HDF5 files in the directory
# Define unit base for the simulation
unit_base = {
"UnitLength_in_cm": 3.08568e21,
"UnitMass_in_g": 1.989e43,
"UnitVelocity_in_cm_per_s": 100000,
}

# Set the bounding box for the simulation
bbox_lim = 1e5
bbox = [[-bbox_lim, bbox_lim], [-bbox_lim, bbox_lim], [-bbox_lim, bbox_lim]]

for hdf5_file in os.listdir(snapshot_dir):
    if hdf5_file.startswith("snapshot_"):
        # Define the full path to the HDF5 file
        hdf5_path = os.path.join(snapshot_dir, hdf5_file)

        # Load the dataset using yt
        ds = yt.load(hdf5_path, unit_base=unit_base, bounding_box=bbox)
        ds.index

        # Access all data in the dataset
        ad = ds.all_data()

        # Create a projection plot along the x-axis for gas density
        px = yt.ProjectionPlot(ds, "x", ("gas", "density", ), center=[25000, 25000, 25000], width=[65000, 65000, 65000])
        px.show()

        # Save the projection plot as a JPG file
        jpg_file = os.path.splitext(hdf5_file)[0] + '.jpg'
        jpg_path = os.path.join(snapshot_dir, 'first snapshots', jpg_file)
        px.save(jpg_path)
# Out:
# yt : [INFO     ] 2023-12-11 21:37:09,143 Calculating time from 2.500e-01 to be 6.667e+16 seconds
# yt : [INFO     ] 2023-12-11 21:37:09,272 Parameters: current_time              = 6.66674637928125e+16 s
# yt : [INFO     ] 2023-12-11 21:37:09,276 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2023-12-11 21:37:09,278 Parameters: domain_left_edge          = [-100000. -100000. -100000.]
# yt : [INFO     ] 2023-12-11 21:37:09,282 Parameters: domain_right_edge         = [100000. 100000. 100000.]
# yt : [INFO     ] 2023-12-11 21:37:09,284 Parameters: cosmological_simulation   = True
# yt : [INFO     ] 2023-12-11 21:37:09,286 Parameters: current_redshift          = 2.9999553718031304
# yt : [INFO     ] 2023-12-11 21:37:09,287 Parameters: omega_lambda              = 0.7
# yt : [INFO     ] 2023-12-11 21:37:09,288 Parameters: omega_matter              = 0.3
# yt : [INFO     ] 2023-12-11 21:37:09,291 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-12-11 21:37:09,292 Parameters: hubble_constant           = 0.7
# yt : [WARNING  ] 2023-12-11 21:37:09,293 A bounding box was explicitly specified, so we are disabling periodicity.
# yt : [INFO     ] 2023-12-11 21:37:10,082 Allocating for 6.554e+04 particles
# yt : [INFO     ] 2023-12-11 21:37:10,815 xlim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:10,816 ylim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:10,824 xlim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:10,827 ylim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:10,832 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-12-11 21:37:14,580 Saving plot /content/drive/MyDrive/firstoutput/first snapshots/snapshot_001.jpg
# yt : [INFO     ] 2023-12-11 21:37:15,744 Calculating time from 3.311e-01 to be 1.008e+17 seconds
# yt : [INFO     ] 2023-12-11 21:37:15,821 Parameters: current_time              = 1.0083848604073184e+17 s
# yt : [INFO     ] 2023-12-11 21:37:15,823 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2023-12-11 21:37:15,827 Parameters: domain_left_edge          = [-100000. -100000. -100000.]
# yt : [INFO     ] 2023-12-11 21:37:15,830 Parameters: domain_right_edge         = [100000. 100000. 100000.]
# yt : [INFO     ] 2023-12-11 21:37:15,832 Parameters: cosmological_simulation   = True
# yt : [INFO     ] 2023-12-11 21:37:15,834 Parameters: current_redshift          = 2.0200695225827228
# yt : [INFO     ] 2023-12-11 21:37:15,835 Parameters: omega_lambda              = 0.7
# yt : [INFO     ] 2023-12-11 21:37:15,836 Parameters: omega_matter              = 0.3
# yt : [INFO     ] 2023-12-11 21:37:15,837 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-12-11 21:37:15,838 Parameters: hubble_constant           = 0.7
# yt : [WARNING  ] 2023-12-11 21:37:15,840 A bounding box was explicitly specified, so we are disabling periodicity.
# yt : [INFO     ] 2023-12-11 21:37:16,846 Allocating for 6.554e+04 particles
# yt : [INFO     ] 2023-12-11 21:37:17,599 xlim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:17,602 ylim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:17,608 xlim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:17,611 ylim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:17,619 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-12-11 21:37:22,135 Saving plot /content/drive/MyDrive/firstoutput/first snapshots/snapshot_002.jpg
# yt : [INFO     ] 2023-12-11 21:37:22,967 Calculating time from 1.656e-01 to be 3.608e+16 seconds
# yt : [INFO     ] 2023-12-11 21:37:23,059 Parameters: current_time              = 3.608035638164642e+16 s
# yt : [INFO     ] 2023-12-11 21:37:23,062 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2023-12-11 21:37:23,064 Parameters: domain_left_edge          = [-100000. -100000. -100000.]
# yt : [INFO     ] 2023-12-11 21:37:23,066 Parameters: domain_right_edge         = [100000. 100000. 100000.]
# yt : [INFO     ] 2023-12-11 21:37:23,069 Parameters: cosmological_simulation   = True
# yt : [INFO     ] 2023-12-11 21:37:23,070 Parameters: current_redshift          = 5.040105350007158
# yt : [INFO     ] 2023-12-11 21:37:23,071 Parameters: omega_lambda              = 0.7
# yt : [INFO     ] 2023-12-11 21:37:23,072 Parameters: omega_matter              = 0.3
# yt : [INFO     ] 2023-12-11 21:37:23,073 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-12-11 21:37:23,074 Parameters: hubble_constant           = 0.7
# yt : [WARNING  ] 2023-12-11 21:37:23,076 A bounding box was explicitly specified, so we are disabling periodicity.
# yt : [INFO     ] 2023-12-11 21:37:23,101 Allocating for 6.554e+04 particles
# yt : [INFO     ] 2023-12-11 21:37:24,090 xlim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:24,092 ylim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:24,098 xlim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:24,100 ylim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:24,103 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-12-11 21:37:29,135 Saving plot /content/drive/MyDrive/firstoutput/first snapshots/snapshot_000.jpg
# yt : [INFO     ] 2023-12-11 21:37:30,363 Calculating time from 5.000e-01 to be 1.815e+17 seconds
# yt : [INFO     ] 2023-12-11 21:37:30,447 Parameters: current_time              = 1.8150977132118368e+17 s
# yt : [INFO     ] 2023-12-11 21:37:30,449 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2023-12-11 21:37:30,453 Parameters: domain_left_edge          = [-100000. -100000. -100000.]
# yt : [INFO     ] 2023-12-11 21:37:30,455 Parameters: domain_right_edge         = [100000. 100000. 100000.]
# yt : [INFO     ] 2023-12-11 21:37:30,460 Parameters: cosmological_simulation   = True
# yt : [INFO     ] 2023-12-11 21:37:30,462 Parameters: current_redshift          = 0.9999888429196624
# yt : [INFO     ] 2023-12-11 21:37:30,464 Parameters: omega_lambda              = 0.7
# yt : [INFO     ] 2023-12-11 21:37:30,466 Parameters: omega_matter              = 0.3
# yt : [INFO     ] 2023-12-11 21:37:30,468 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-12-11 21:37:30,473 Parameters: hubble_constant           = 0.7
# yt : [WARNING  ] 2023-12-11 21:37:30,476 A bounding box was explicitly specified, so we are disabling periodicity.
# yt : [INFO     ] 2023-12-11 21:37:31,333 Allocating for 6.554e+04 particles
# yt : [INFO     ] 2023-12-11 21:37:32,071 xlim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:32,072 ylim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:32,078 xlim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:32,080 ylim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:32,085 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-12-11 21:37:35,428 Saving plot /content/drive/MyDrive/firstoutput/first snapshots/snapshot_003.jpg
# yt : [INFO     ] 2023-12-11 21:37:36,858 Calculating time from 1.000e+00 to be 4.250e+17 seconds
# yt : [INFO     ] 2023-12-11 21:37:36,963 Parameters: current_time              = 4.249860691601938e+17 s
# yt : [INFO     ] 2023-12-11 21:37:36,969 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2023-12-11 21:37:36,971 Parameters: domain_left_edge          = [-100000. -100000. -100000.]
# yt : [INFO     ] 2023-12-11 21:37:36,973 Parameters: domain_right_edge         = [100000. 100000. 100000.]
# yt : [INFO     ] 2023-12-11 21:37:36,975 Parameters: cosmological_simulation   = True
# yt : [INFO     ] 2023-12-11 21:37:36,976 Parameters: current_redshift          = 0.0
# yt : [INFO     ] 2023-12-11 21:37:36,977 Parameters: omega_lambda              = 0.7
# yt : [INFO     ] 2023-12-11 21:37:36,978 Parameters: omega_matter              = 0.3
# yt : [INFO     ] 2023-12-11 21:37:36,979 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2023-12-11 21:37:36,981 Parameters: hubble_constant           = 0.7
# yt : [WARNING  ] 2023-12-11 21:37:36,982 A bounding box was explicitly specified, so we are disabling periodicity.
# yt : [INFO     ] 2023-12-11 21:37:38,355 Allocating for 6.554e+04 particles
# yt : [INFO     ] 2023-12-11 21:37:39,439 xlim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:39,444 ylim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:39,452 xlim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:39,453 ylim = -7500.000000 57500.000000
# yt : [INFO     ] 2023-12-11 21:37:39,457 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-12-11 21:37:44,015 Saving plot /content/drive/MyDrive/firstoutput/first snapshots/snapshot_004.jpg

# %%
unit_base = {
"UnitLength_in_cm": 3.08568e21,
"UnitMass_in_g": 1.989e43,
"UnitVelocity_in_cm_per_s": 100000,
}
bbox_lim = 1e5
bbox = [[-bbox_lim, bbox_lim], [-bbox_lim, bbox_lim], [-bbox_lim, bbox_lim]]

# %%
framerate = 5
snapshots_dir = "/content/drive/MyDrive/final snapshots/snapshots"
movie_dir = "/content/drive/MyDrive"

# %%
def filepathNum(filepath):
    # take filename out of filepath
    filename = os.path.basename(filepath)
    # take the value, between the _ and the .
    number = filename.split("_")[-1]
    number = number.split(".")[0]
    # Turn it into integer
    number = int(number)
    # Return result
    return number

# %%
import os
import imageio

def create_movie(input_dir, output_file, file_prefix='', framerate=24):
    # Get all JPG files in the input directory
    jpg_files = sorted([f for f in os.listdir(input_dir) if f.startswith(file_prefix) and f.endswith('.jpg')])

    # Create a list to store the images
    images = []

    # Read each JPG file and append to the images list
    for jpg_file in jpg_files:
        image_path = os.path.join(input_dir, jpg_file)
        images.append(imageio.imread(image_path))

    # # Create the movie (MP4) using imageio
    # output_path = os.path.join(input_dir, output_file)
    # imageio.mimsave(output_path, images, fps=framerate)

# # Example usage
# input_directory = '/content/drive/MyDrive/final snapshots/snapshots'
# output_movie_file = 'FINAL lcdm-gas.mp4'
# create_movie(input_directory, output_movie_file, file_prefix='snapshot_', framerate=15)
# Out:
# <ipython-input-35-4068ee0f78fe>:14: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images.append(imageio.imread(image_path))
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1085, 920) to (1088, 928) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
